# %% [markdown]
# <a href="https://colab.research.google.com/github/NourdotSiwar/Advanced_WaterFitBit/blob/master/Day_10/Regularization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image_2021-10-30_133041.png](data:image/png;base64,...)

# %% [markdown]
# #Day 10 Objectives:
# * To acquaint you with the problem of overfit models and to mitigate it with regularization

# %% [markdown]
# # Applying regularization
#
# You may be familiar with Occam's Razor principle: given two explanations for something, the explanation most likely to be correct is the "simplest" one, the one that makes the least amount of assumptions. This also applies to the models learned by neural networks: given some training data and a network architecture, there are multiple sets of weights values (multiple models) that could explain the data, and simpler models are less likely to overfit than complex ones.
#
# A "simple model" in this context is a model where the distribution of parameter values has less entropy (or a model with fewer parameters altogether, as we saw in the section above). Thus a common way to mitigate overfitting is to put constraints on the complexity of a network by forcing its weights only to take small values, which makes the distribution of weight values more "regular". This is called "weight regularization", and it is done by adding to the loss function of the network a cost associated with having large weights. This cost comes in two flavors:
#
# L1 regularization, where the cost added is proportional to the absolute value of the weights coefficients (i.e. to what is called the "L1 norm" of the weights).
#
# L2 regularization, where the cost added is proportional to the square of the value of the weights coefficients (i.e. to what is called the squared "L2 norm" of the weights). L2 regularization is also called weight decay in the context of neural networks. Don't let the different name confuse you: weight decay is mathematically the exact same as L2 regularization.
#
# L1 regularization pushes weights towards exactly zero encouraging a sparse model. L2 regularization will penalize the weights parameters without making them sparse since the penalty goes to zero for small weights-one reason why L2 is more common.
#
# In `tf.keras`, weight regularization is added by passing weight regularizer instances to layers as keyword arguments. Let's add L2 weight regularization now.

# %%
# Basic packages
import pandas as pd 
import numpy as np
import re
import collections
import matplotlib.pyplot as plt
from pathlib import Path

# Packages for data preparation
from sklearn.model_selection import train_test_split
from nltk.corpus import stopwords
from keras.preprocessing.text import Tokenizer
from keras.utils.np_utils import to_categorical
from sklearn.preprocessing import LabelEncoder

import nltk
nltk.download('stopwords')

# Packages for modeling
import tensorflow as tf
from tensorflow.keras import models
from tensorflow.keras import layers
from tensorflow.keras import regularizers


NB_WORDS = 10000  # Parameter indicating the number of words we'll put in the dictionary
NB_START_EPOCHS = 20  # Number of epochs we usually start to train with
BATCH_SIZE = 512  # Size of the batches used in the mini-batch gradient descent
MAX_LEN = 20  # Maximum number of words in a sequence


root = Path('../content/')
input_path = root / 'input/' 
ouput_path = root / 'output/'
source_path = root / 'source/'

# %%
reg_model = models.Sequential()
reg_model.add(layers.Dense(64, kernel_regularizer=regularizers.l2(0.001), activation='relu', input_shape=(NB_WORDS,)))
reg_model.add(layers.Dense(64, kernel_regularizer=regularizers.l2(0.001), activation='relu'))
reg_model.add(layers.Dense(3, activation='softmax'))
reg_model.summary()
# Out:
# Model: "sequential_13"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_37 (Dense)            (None, 64)                640064
#
#  dense_38 (Dense)            (None, 64)                4160
#
#  dense_39 (Dense)            (None, 3)                 195
#
# =================================================================
# Total params: 644,419
# Trainable params: 644,419
# Non-trainable params: 0
# _________________________________________________________________

# %%
def deep_model(model, X_train, y_train, X_valid, y_valid):
    model.compile(optimizer='rmsprop'
                  , loss='categorical_crossentropy'
                  , metrics=['accuracy'])
    
    history = model.fit(X_train
                       , y_train
                       , epochs=NB_START_EPOCHS
                       , batch_size=BATCH_SIZE
                       , validation_data=(X_valid, y_valid)
                       , verbose=1)
    return history

    
def eval_metric(model, history, metric_name):
    metric = history.history[metric_name]
    val_metric = history.history['val_' + metric_name]

    e = range(1, NB_START_EPOCHS + 1)

    plt.plot(e, metric, 'bo', label='Train ' + metric_name)
    plt.plot(e, val_metric, 'b', label='Validation ' + metric_name)
    plt.xlabel('Epoch number')
    plt.ylabel(metric_name)
    plt.title('Comparing training and validation ' + metric_name + ' for ' + model.name)
    plt.legend()
    plt.show()

def test_model(model, X_train, y_train, X_test, y_test, epoch_stop):
  model.fit(X_train
            , y_train
            , epochs=epoch_stop
            , batch_size=BATCH_SIZE
            , verbose=1)
  results = model.evaluate(X_test, y_test)
  print()
  print('Test accuracy: {0:.2f}%'.format(results[1]*100))
  return results

def remove_stopwords(input_text):
    stopwords_list = stopwords.words('english')
    # Some words which might indicate a certain sentiment are kept via a whitelist
    whitelist = ["n't", "not", "no"]
    words = input_text.split() 
    clean_words = [word for word in words if (word not in stopwords_list or word in whitelist) and len(word) > 1] 
    return " ".join(clean_words) 

def remove_mentions(input_text):
    return re.sub(r'@\w+', '', input_text)
     
def compare_models_by_metric(model_1, model_2, model_hist_1, model_hist_2, metric):
    metric_model_1 = model_hist_1.history[metric]
    metric_model_2 = model_hist_2.history[metric]

    e = range(1, NB_START_EPOCHS + 1)
    
    metrics_dict = {
        'acc' : 'Training Accuracy',
        'loss' : 'Training Loss',
        'val_acc' : 'Validation accuracy',
        'val_loss' : 'Validation loss'
    }
    
    metric_label = metrics_dict[metric]

    plt.plot(e, metric_model_1, 'bo', label=model_1.name)
    plt.plot(e, metric_model_2, 'b', label=model_2.name)
    plt.xlabel('Epoch number')
    plt.ylabel(metric_label)
    plt.title('Comparing ' + metric_label + ' between models')
    plt.legend()
    plt.show()


def optimal_epoch(model_hist):
    min_epoch = np.argmin(model_hist.history['val_loss']) + 1
    print("Minimum validation loss reached in epoch {}".format(min_epoch))
    return min_epoch
  
! gdown --id 1QFupRVBpstzf_D6NiFvYQIO-MPuiwG9u 
! mkdir input/ 
! mv Tweets.csv input/


df = pd.read_csv(input_path / 'Tweets.csv')
df = df.reindex(np.random.permutation(df.index))  
df = df[['text', 'airline_sentiment']]
df.text = df.text.apply(remove_stopwords).apply(remove_mentions)


X_train, X_test, y_train, y_test = train_test_split(df.text, df.airline_sentiment, test_size=0.1, random_state=37)
print('# Train data samples:', X_train.shape[0])
print('# Test data samples:', X_test.shape[0])
assert X_train.shape[0] == y_train.shape[0]
assert X_test.shape[0] == y_test.shape[0]

tk = Tokenizer(num_words=NB_WORDS,
               filters='!"#$%&()*+,-./:;<=>?@[\\]^_`{|}~\t\n',
               lower=True,
               char_level=False,
               split=' ')
tk.fit_on_texts(X_train)

print('Fitted tokenizer on {} documents'.format(tk.document_count))
print('{} words in dictionary'.format(tk.num_words))
print('Top 5 most common words are:', collections.Counter(tk.word_counts).most_common(5))


X_train_oh = tk.texts_to_matrix(X_train, mode='binary')
X_test_oh = tk.texts_to_matrix(X_test, mode='binary')


le = LabelEncoder()
y_train_le = le.fit_transform(y_train)
y_test_le = le.transform(y_test)
y_train_oh = to_categorical(y_train_le)
y_test_oh = to_categorical(y_test_le)

print('"{}" is converted into {}'.format(y_train[0], y_train_le[0]))
print('"{}" is converted into {}'.format(y_train_le[0], y_train_oh[0]))

X_train_rest, X_valid, y_train_rest, y_valid = train_test_split(X_train_oh, y_train_oh, test_size=0.1, random_state=37)

assert X_valid.shape[0] == y_valid.shape[0]
assert X_train_rest.shape[0] == y_train_rest.shape[0]

print('Shape of validation set:',X_valid.shape)
# Out:
# /usr/local/lib/python3.8/dist-packages/gdown/cli.py:127: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1QFupRVBpstzf_D6NiFvYQIO-MPuiwG9u
# To: /content/Tweets.csv
# 100% 3.42M/3.42M [00:00<00:00, 181MB/s]
# mkdir: cannot create directory ‘input/’: File exists
# # Train data samples: 13176
# # Test data samples: 1464
# Fitted tokenizer on 13176 documents
# 10000 words in dictionary
# Top 5 most common words are: [('flight', 3534), ('not', 1442), ('no', 1349), ('get', 1206), ('t', 1104)]
# "neutral" is converted into 2
# "2" is converted into [0. 0. 1.]
# Shape of validation set: (1318, 10000)

# %%
reg_history = deep_model(reg_model, X_train_rest, y_train_rest, X_valid, y_valid)
reg_min = optimal_epoch(reg_history)
# Out:
# Epoch 1/20
# 24/24 [==============================] - 2s 63ms/step - loss: 1.0728 - accuracy: 0.6070 - val_loss: 0.9283 - val_accuracy: 0.6259
# Epoch 2/20
# 24/24 [==============================] - 1s 59ms/step - loss: 0.8160 - accuracy: 0.7100 - val_loss: 0.7753 - val_accuracy: 0.7382
# Epoch 3/20
# 24/24 [==============================] - 4s 152ms/step - loss: 0.6636 - accuracy: 0.8059 - val_loss: 0.6920 - val_accuracy: 0.7815
# Epoch 4/20
# 24/24 [==============================] - 1s 62ms/step - loss: 0.5632 - accuracy: 0.8455 - val_loss: 0.6744 - val_accuracy: 0.7860
# Epoch 5/20
# 24/24 [==============================] - 1s 45ms/step - loss: 0.5017 - accuracy: 0.8634 - val_loss: 0.6468 - val_accuracy: 0.7906
# Epoch 6/20
# 24/24 [==============================] - 1s 36ms/step - loss: 0.4545 - accuracy: 0.8822 - val_loss: 0.6495 - val_accuracy: 0.7807
# Epoch 7/20
# 24/24 [==============================] - 1s 38ms/step - loss: 0.4207 - accuracy: 0.8916 - val_loss: 0.6600 - val_accuracy: 0.7853
# Epoch 8/20
# 24/24 [==============================] - 1s 57ms/step - loss: 0.3910 - accuracy: 0.9043 - val_loss: 0.6670 - val_accuracy: 0.7785
# Epoch 9/20
# 24/24 [==============================] - 1s 53ms/step - loss: 0.3683 - accuracy: 0.9123 - val_loss: 0.6720 - val_accuracy: 0.7830
# Epoch 10/20
# 24/24 [==============================] - 1s 36ms/step - loss: 0.3468 - accuracy: 0.9229 - val_loss: 0.6932 - val_accuracy: 0.7898
# Epoch 11/20
# 24/24 [==============================] - 1s 36ms/step - loss: 0.3301 - accuracy: 0.9282 - val_loss: 0.7161 - val_accuracy: 0.7830
# Epoch 12/20
# 24/24 [==============================] - 1s 34ms/step - loss: 0.3143 - accuracy: 0.9343 - val_loss: 0.7313 - val_accuracy: 0.7709
# Epoch 13/20
# 24/24 [==============================] - 1s 37ms/step - loss: 0.3023 - accuracy: 0.9385 - val_loss: 0.7287 - val_accuracy: 0.7663
# Epoch 14/20
# 24/24 [==============================] - 1s 37ms/step - loss: 0.2883 - accuracy: 0.9452 - val_loss: 0.7507 - val_accuracy: 0.7754
# Epoch 15/20
# 24/24 [==============================] - 1s 37ms/step - loss: 0.2810 - accuracy: 0.9448 - val_loss: 0.7670 - val_accuracy: 0.7625
# Epoch 16/20
# 24/24 [==============================] - 1s 35ms/step - loss: 0.2703 - accuracy: 0.9493 - val_loss: 0.7624 - val_accuracy: 0.7671
# Epoch 17/20
# 24/24 [==============================] - 1s 36ms/step - loss: 0.2599 - accuracy: 0.9548 - val_loss: 0.7883 - val_accuracy: 0.7595
# Epoch 18/20
# 24/24 [==============================] - 1s 35ms/step - loss: 0.2526 - accuracy: 0.9556 - val_loss: 0.7831 - val_accuracy: 0.7656
# Epoch 19/20
# 24/24 [==============================] - 1s 35ms/step - loss: 0.2436 - accuracy: 0.9587 - val_loss: 0.8146 - val_accuracy: 0.7625
# Epoch 20/20
# 24/24 [==============================] - 1s 36ms/step - loss: 0.2375 - accuracy: 0.9617 - val_loss: 0.8121 - val_accuracy: 0.7580
# Minimum validation loss reached in epoch 5

# %% [markdown]
# For the regularized model we notice that it starts overfitting in the same epoch as the baseline model. However, the loss increases much slower afterwards.

# %%
eval_metric(reg_model, reg_history, 'loss')

# %%
compare_models_by_metric(base_model, reg_model, base_history, reg_history, 'val_loss')

# %% [markdown]
# ## Question 1
#
# First identify (provide the name of) and then code the regularizer which is used in the following loss function:
#
# $$cost = (\mathbf{y} - \mathbf{x}W)^2 + λ||W||$$
#
# Let's assume $w = [-5, 4, -3, 2, 1]$

# %% [markdown]
# ###  Answer 1

# %%
weights = [-5, 4, -3, 2, 1]
x = X_train_rest
y = y_train_rest

def l1_norm(weights):
    # The regularizer used is L1 regularization,
    # because that is "where the cost added is proportional 
    # to the absolute value of the weights coefficients 
    # (i.e. to what is called the "L1 norm" of the weights)."

    reg = np.square(y - (x*weights)) + ((0.01) * np.abs(weights))
    return reg

print(l1_norm(weights))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-44-aa3e562c15c6> in <module>
#      12     return reg
#      13
# ---> 14 print(l1_norm(weights))
#
# <ipython-input-44-aa3e562c15c6> in l1_norm(weights)
#       9     # (i.e. to what is called the "L1 norm" of the weights)."
#      10
# ---> 11     reg = np.square(y - (x*weights))
#      12     return reg
#      13
#
# ValueError: operands could not be broadcast together with shapes (11858,10000) (5,)

# %% [markdown]
# ## Question 2
#
# First identify (provide the name of) and then code the regularizer which is used in the following loss function:
#
# $$cost = (\mathbf{y} - \mathbf{x}W)^2 + λ||W||_2^2$$
#
# Let's assume $w = [-5, 4, -3, 2, 1]$

# %% [markdown]
# ###  Answer 2

# %%
weights = [-5, 4, -3, 2, 1]

x = X_train_rest
y = y_train_rest

def l2_norm(weights):
    # The regulizer used is L2 regularization, 
    # "where the cost added is proportional to the square of the value of the weights coefficients 
    # (i.e. to what is called the squared "L2 norm" of the weights)."

    reg = np.square(y - (x*weights)) + ((0.01) * np.square(np.abs(weights)))
    return reg

print(l2_norm(weights))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-45-eb01f083d2c9> in <module>
#      12     return reg
#      13
# ---> 14 print(l2_norm(weights))
#
# <ipython-input-45-eb01f083d2c9> in l2_norm(weights)
#       9     # (i.e. to what is called the squared "L2 norm" of the weights)."
#      10
# ---> 11     reg = np.square(y - (x*weights)) + ((0.01) * np.square(np.abs(weights)))
#      12     return reg
#      13
#
# ValueError: operands could not be broadcast together with shapes (11858,10000) (5,)

# %% [markdown]
# ## Adding dropout layers
# Add dropout
# Dropout is one of the most effective and most commonly used regularization techniques for neural networks, developed by Hinton and his students at the University of Toronto.
#
# The intuitive explanation for dropout is that because individual nodes in the network cannot rely on the output of the others, each node must output features that are useful on their own.
#
# Dropout, applied to a layer, consists of randomly "dropping out" (i.e. set to zero) a number of output features of the layer during training. Let's say a given layer would normally have returned a vector [0.2, 0.5, 1.3, 0.8, 1.1] for a given input sample during training; after applying dropout, this vector will have a few zero entries distributed at random, e.g. [0, 0.5, 1.3, 0, 1.1].
#
# The "dropout rate" is the fraction of the features that are being zeroed-out; it is usually set between 0.2 and 0.5. At test time, no units are dropped out, and instead the layer's output values are scaled down by a factor equal to the dropout rate, so as to balance for the fact that more units are active than at training time.
#
# In `tf.keras` you can introduce dropout in a network via the Dropout layer, which gets applied to the output of layer right before.
#
# Let's add two Dropout layers in our network to see how well they do at reducing overfitting:

# %%
drop_model = models.Sequential()
drop_model.add(layers.Dense(64, activation='relu', input_shape=(NB_WORDS,)))
drop_model.add(layers.Dropout(0.5))
drop_model.add(layers.Dense(64, activation='relu'))
drop_model.add(layers.Dropout(0.5))
drop_model.add(layers.Dense(3, activation='softmax'))
drop_model.summary()
# Out:
# Model: "sequential_14"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_40 (Dense)            (None, 64)                640064
#
#  dropout_14 (Dropout)        (None, 64)                0
#
#  dense_41 (Dense)            (None, 64)                4160
#
#  dropout_15 (Dropout)        (None, 64)                0
#
#  dense_42 (Dense)            (None, 3)                 195
#
# =================================================================
# Total params: 644,419
# Trainable params: 644,419
# Non-trainable params: 0
# _________________________________________________________________

# %%
drop_history = deep_model(drop_model, X_train_rest, y_train_rest, X_valid, y_valid)
drop_min = optimal_epoch(drop_history)
# Out:
# Epoch 1/20
# 24/24 [==============================] - 2s 46ms/step - loss: 0.9440 - accuracy: 0.5906 - val_loss: 0.8174 - val_accuracy: 0.6123
# Epoch 2/20
# 24/24 [==============================] - 1s 37ms/step - loss: 0.7635 - accuracy: 0.6441 - val_loss: 0.7180 - val_accuracy: 0.6662
# Epoch 3/20
# 24/24 [==============================] - 1s 37ms/step - loss: 0.6598 - accuracy: 0.7243 - val_loss: 0.6435 - val_accuracy: 0.7299
# Epoch 4/20
# 24/24 [==============================] - 1s 58ms/step - loss: 0.5682 - accuracy: 0.7899 - val_loss: 0.5854 - val_accuracy: 0.7769
# Epoch 5/20
# 24/24 [==============================] - 1s 52ms/step - loss: 0.5079 - accuracy: 0.8200 - val_loss: 0.5545 - val_accuracy: 0.7800
# Epoch 6/20
# 24/24 [==============================] - 1s 36ms/step - loss: 0.4554 - accuracy: 0.8382 - val_loss: 0.5455 - val_accuracy: 0.7883
# Epoch 7/20
# 24/24 [==============================] - 1s 36ms/step - loss: 0.4172 - accuracy: 0.8533 - val_loss: 0.5333 - val_accuracy: 0.7876
# Epoch 8/20
# 24/24 [==============================] - 1s 35ms/step - loss: 0.3800 - accuracy: 0.8647 - val_loss: 0.5373 - val_accuracy: 0.7997
# Epoch 9/20
# 24/24 [==============================] - 1s 36ms/step - loss: 0.3525 - accuracy: 0.8817 - val_loss: 0.5424 - val_accuracy: 0.8020
# Epoch 10/20
# 24/24 [==============================] - 1s 35ms/step - loss: 0.3240 - accuracy: 0.8889 - val_loss: 0.5434 - val_accuracy: 0.7951
# Epoch 11/20
# 24/24 [==============================] - 1s 36ms/step - loss: 0.2952 - accuracy: 0.9002 - val_loss: 0.5557 - val_accuracy: 0.7929
# Epoch 12/20
# 24/24 [==============================] - 1s 35ms/step - loss: 0.2844 - accuracy: 0.9035 - val_loss: 0.5763 - val_accuracy: 0.7936
# Epoch 13/20
# 24/24 [==============================] - 1s 35ms/step - loss: 0.2603 - accuracy: 0.9122 - val_loss: 0.5833 - val_accuracy: 0.7891
# Epoch 14/20
# 24/24 [==============================] - 1s 35ms/step - loss: 0.2443 - accuracy: 0.9185 - val_loss: 0.5926 - val_accuracy: 0.7853
# Epoch 15/20
# 24/24 [==============================] - 1s 36ms/step - loss: 0.2279 - accuracy: 0.9221 - val_loss: 0.6133 - val_accuracy: 0.7914
# Epoch 16/20
# 24/24 [==============================] - 1s 38ms/step - loss: 0.2067 - accuracy: 0.9313 - val_loss: 0.6303 - val_accuracy: 0.7860
# Epoch 17/20
# 24/24 [==============================] - 1s 60ms/step - loss: 0.1944 - accuracy: 0.9368 - val_loss: 0.6496 - val_accuracy: 0.7876
# Epoch 18/20
# 24/24 [==============================] - 1s 47ms/step - loss: 0.1792 - accuracy: 0.9404 - val_loss: 0.6734 - val_accuracy: 0.7860
# Epoch 19/20
# 24/24 [==============================] - 1s 36ms/step - loss: 0.1683 - accuracy: 0.9448 - val_loss: 0.6929 - val_accuracy: 0.7800
# Epoch 20/20
# 24/24 [==============================] - 1s 35ms/step - loss: 0.1595 - accuracy: 0.9491 - val_loss: 0.7059 - val_accuracy: 0.7853
# Minimum validation loss reached in epoch 7

# %%
eval_metric(drop_model, drop_history, 'loss')

# %% [markdown]
# The model with dropout layers starts overfitting later than the baseline model. The loss also increases slower than the baseline model.

# %%
compare_models_by_metric(base_model, drop_model, base_history, drop_history, 'val_loss')

# %% [markdown]
# The model with the Dropout layers starts overfitting later. Compared to the baseline model the loss also remains much lower.

# %% [markdown]
# ## Combined L2 + dropout

# %%
combined_model = tf.keras.Sequential([
    layers.Dense(512, kernel_regularizer=regularizers.l2(0.0001),
                 activation='relu', input_shape=(NB_WORDS,)),
    layers.Dropout(0.5),
    layers.Dense(512, kernel_regularizer=regularizers.l2(0.0001),
                 activation='relu'),
    layers.Dropout(0.5),
    layers.Dense(512, kernel_regularizer=regularizers.l2(0.0001),
                 activation='relu'),
    layers.Dropout(0.5),
    layers.Dense(512, kernel_regularizer=regularizers.l2(0.0001),
                 activation='relu'),
    layers.Dropout(0.5),
    layers.Dense(3)
])

# %%
combined_history = deep_model(combined_model, X_train_rest, y_train_rest, X_valid, y_valid)
combined_min = optimal_epoch(combined_history)
# Out:
# Epoch 1/20
# 24/24 [==============================] - 6s 225ms/step - loss: 1.5815 - accuracy: 0.1856 - val_loss: 1.0987 - val_accuracy: 0.1017
# Epoch 2/20
# 24/24 [==============================] - 6s 251ms/step - loss: 2.0519 - accuracy: 0.1151 - val_loss: 1.9032 - val_accuracy: 0.5288
# Epoch 3/20
# 24/24 [==============================] - 5s 214ms/step - loss: 1.3112 - accuracy: 0.6213 - val_loss: 1.0609 - val_accuracy: 0.6123
# Epoch 4/20
# 24/24 [==============================] - 6s 247ms/step - loss: 3.3129 - accuracy: 0.7036 - val_loss: 13.0234 - val_accuracy: 0.6798
# Epoch 5/20
# 24/24 [==============================] - 5s 215ms/step - loss: 10.9638 - accuracy: 0.7075 - val_loss: 10.4597 - val_accuracy: 0.6259
# Epoch 6/20
# 24/24 [==============================] - 6s 250ms/step - loss: 7.9150 - accuracy: 0.6445 - val_loss: 5.0493 - val_accuracy: 0.6882
# Epoch 7/20
# 24/24 [==============================] - 5s 219ms/step - loss: 8.2586 - accuracy: 0.6878 - val_loss: 4.6511 - val_accuracy: 0.6123
# Epoch 8/20
# 24/24 [==============================] - 6s 249ms/step - loss: 6.3748 - accuracy: 0.6297 - val_loss: 5.3910 - val_accuracy: 0.6123
# Epoch 9/20
# 24/24 [==============================] - 5s 215ms/step - loss: 6.1442 - accuracy: 0.6297 - val_loss: 5.7882 - val_accuracy: 0.6123
# Epoch 10/20
# 24/24 [==============================] - 6s 232ms/step - loss: 6.0686 - accuracy: 0.6297 - val_loss: 5.9531 - val_accuracy: 0.6123
# Epoch 11/20
# 24/24 [==============================] - 6s 224ms/step - loss: 6.0229 - accuracy: 0.6297 - val_loss: 5.9470 - val_accuracy: 0.6123
# Epoch 12/20
# 24/24 [==============================] - 5s 217ms/step - loss: 6.0930 - accuracy: 0.6297 - val_loss: 6.3201 - val_accuracy: 0.6123
# Epoch 13/20
# 24/24 [==============================] - 6s 248ms/step - loss: 6.0083 - accuracy: 0.6297 - val_loss: 6.3144 - val_accuracy: 0.6123
# Epoch 14/20
# 24/24 [==============================] - 5s 213ms/step - loss: 5.9292 - accuracy: 0.6297 - val_loss: 6.3088 - val_accuracy: 0.6123
# Epoch 15/20
# 24/24 [==============================] - 6s 248ms/step - loss: 5.9644 - accuracy: 0.6297 - val_loss: 6.3033 - val_accuracy: 0.6123
# Epoch 16/20
# 24/24 [==============================] - 5s 216ms/step - loss: 5.8387 - accuracy: 0.6321 - val_loss: 3.7687 - val_accuracy: 0.6760
# Epoch 17/20
# 24/24 [==============================] - 6s 251ms/step - loss: 4.8306 - accuracy: 0.6908 - val_loss: 3.7620 - val_accuracy: 0.6851
# Epoch 18/20
# 24/24 [==============================] - 5s 219ms/step - loss: 6.1193 - accuracy: 0.6892 - val_loss: 3.7571 - val_accuracy: 0.6912
# Epoch 19/20
# 24/24 [==============================] - 6s 250ms/step - loss: 8.4208 - accuracy: 0.6612 - val_loss: 10.0262 - val_accuracy: 0.6123
# Epoch 20/20
# 24/24 [==============================] - 5s 217ms/step - loss: 8.4033 - accuracy: 0.6297 - val_loss: 3.5769 - val_accuracy: 0.6123
# Minimum validation loss reached in epoch 3

# %%
eval_metric(combined_model, combined_history, 'loss')

# %%
compare_models_by_metric(base_model, combined_model, base_history, combined_history, 'val_loss')

# %% [markdown]
# ## Question 3
#
# When does it make sense to add both L2 regularization and Dropout?
#
# And what did doing so achieve in this case?

# %% [markdown]
# ### Answer 3
#
# It makes sense to add both L2 regularization and Drouput when we want to lower the loss because while L2 helps weights value almost towards zero and penalizing large weights, dropout would contribute by selecting random nodes and removing them. With both combinations this helps increase accuracy. However, this does not always work. In this case, adding both did not achieve higher accuracy. When using dropout by itself, accuracy was at 0.9, whereas adding both lowered accuracy to 0.6

# %% [markdown]
# #Training on the full train data and evaluation on test dataAt first sight the reduced model seems to be the best model for generalization. But let's check that on the test set.

# %%
base_results = test_model(base_model, X_train_oh, y_train_oh, X_test_oh, y_test_oh, base_min)
# Out:
# Epoch 1/5
# 26/26 [==============================] - 1s 38ms/step - loss: 0.9296 - accuracy: 0.6677
# Epoch 2/5
# 26/26 [==============================] - 1s 35ms/step - loss: 0.5373 - accuracy: 0.7896
# Epoch 3/5
# 26/26 [==============================] - 1s 33ms/step - loss: 0.3976 - accuracy: 0.8515
# Epoch 4/5
# 26/26 [==============================] - 1s 34ms/step - loss: 0.3016 - accuracy: 0.8909
# Epoch 5/5
# 26/26 [==============================] - 1s 32ms/step - loss: 0.2306 - accuracy: 0.9227
# 46/46 [==============================] - 0s 4ms/step - loss: 0.5838 - accuracy: 0.7835
#
# Test accuracy: 78.35%

# %%
reduced_model = models.Sequential()
reduced_model.add(layers.Dense(16, activation='relu', input_shape=(NB_WORDS,)))
reduced_model.add(layers.Dense(3, activation='softmax'))
reduced_model.summary()

reduced_history = deep_model(reduced_model, X_train_rest, y_train_rest, X_valid, y_valid)
reduced_min = optimal_epoch(reduced_history)
     

reduced_results = test_model(reduced_model, X_train_oh, y_train_oh, X_test_oh, y_test_oh, reduced_min)
# Out:
# Model: "sequential_16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_48 (Dense)            (None, 16)                160016
#
#  dense_49 (Dense)            (None, 3)                 51
#
# =================================================================
# Total params: 160,067
# Trainable params: 160,067
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 24/24 [==============================] - 1s 28ms/step - loss: 1.0459 - accuracy: 0.6144 - val_loss: 0.9931 - val_accuracy: 0.6700
# Epoch 2/20
# 24/24 [==============================] - 0s 19ms/step - loss: 0.9371 - accuracy: 0.7059 - val_loss: 0.8974 - val_accuracy: 0.6889
# Epoch 3/20
# 24/24 [==============================] - 0s 18ms/step - loss: 0.8327 - accuracy: 0.7366 - val_loss: 0.8094 - val_accuracy: 0.7064
# Epoch 4/20
# 24/24 [==============================] - 0s 20ms/step - loss: 0.7374 - accuracy: 0.7597 - val_loss: 0.7361 - val_accuracy: 0.7140
# Epoch 5/20
# 24/24 [==============================] - 0s 18ms/step - loss: 0.6578 - accuracy: 0.7791 - val_loss: 0.6787 - val_accuracy: 0.7314
# Epoch 6/20
# 24/24 [==============================] - 0s 20ms/step - loss: 0.5936 - accuracy: 0.7995 - val_loss: 0.6361 - val_accuracy: 0.7375
# Epoch 7/20
# 24/24 [==============================] - 0s 18ms/step - loss: 0.5420 - accuracy: 0.8178 - val_loss: 0.6035 - val_accuracy: 0.7602
# Epoch 8/20
# 24/24 [==============================] - 0s 20ms/step - loss: 0.5001 - accuracy: 0.8356 - val_loss: 0.5797 - val_accuracy: 0.7754
# Epoch 9/20
# 24/24 [==============================] - 0s 18ms/step - loss: 0.4657 - accuracy: 0.8467 - val_loss: 0.5608 - val_accuracy: 0.7815
# Epoch 10/20
# 24/24 [==============================] - 0s 18ms/step - loss: 0.4369 - accuracy: 0.8536 - val_loss: 0.5495 - val_accuracy: 0.7822
# Epoch 11/20
# 24/24 [==============================] - 0s 21ms/step - loss: 0.4131 - accuracy: 0.8621 - val_loss: 0.5380 - val_accuracy: 0.7868
# Epoch 12/20
# 24/24 [==============================] - 0s 18ms/step - loss: 0.3921 - accuracy: 0.8707 - val_loss: 0.5321 - val_accuracy: 0.7921
# Epoch 13/20
# 24/24 [==============================] - 0s 19ms/step - loss: 0.3735 - accuracy: 0.8757 - val_loss: 0.5273 - val_accuracy: 0.7936
# Epoch 14/20
# 24/24 [==============================] - 0s 18ms/step - loss: 0.3568 - accuracy: 0.8815 - val_loss: 0.5241 - val_accuracy: 0.7929
# Epoch 15/20
# 24/24 [==============================] - 0s 19ms/step - loss: 0.3417 - accuracy: 0.8872 - val_loss: 0.5217 - val_accuracy: 0.7936
# Epoch 16/20
# 24/24 [==============================] - 0s 20ms/step - loss: 0.3281 - accuracy: 0.8930 - val_loss: 0.5201 - val_accuracy: 0.7929
# Epoch 17/20
# 24/24 [==============================] - 0s 19ms/step - loss: 0.3154 - accuracy: 0.8981 - val_loss: 0.5210 - val_accuracy: 0.7944
# Epoch 18/20
# 24/24 [==============================] - 1s 21ms/step - loss: 0.3036 - accuracy: 0.9018 - val_loss: 0.5221 - val_accuracy: 0.7944
# Epoch 19/20
# 24/24 [==============================] - 1s 29ms/step - loss: 0.2924 - accuracy: 0.9045 - val_loss: 0.5240 - val_accuracy: 0.7914
# Epoch 20/20
# 24/24 [==============================] - 1s 29ms/step - loss: 0.2820 - accuracy: 0.9082 - val_loss: 0.5238 - val_accuracy: 0.7936
# Minimum validation loss reached in epoch 16
# Epoch 1/16
# 26/26 [==============================] - 0s 18ms/step - loss: 0.2973 - accuracy: 0.8993
# Epoch 2/16
# 26/26 [==============================] - 0s 17ms/step - loss: 0.2861 - accuracy: 0.9035
# Epoch 3/16
# 26/26 [==============================] - 0s 18ms/step - loss: 0.2756 - accuracy: 0.9069
# Epoch 4/16
# 26/26 [==============================] - 0s 18ms/step - loss: 0.2659 - accuracy: 0.9098
# Epoch 5/16
# 26/26 [==============================] - 0s 18ms/step - loss: 0.2567 - accuracy: 0.9136
# Epoch 6/16
# 26/26 [==============================] - 0s 17ms/step - loss: 0.2481 - accuracy: 0.9182
# Epoch 7/16
# 26/26 [==============================] - 0s 19ms/step - loss: 0.2400 - accuracy: 0.9214
# Epoch 8/16
# 26/26 [==============================] - 0s 18ms/step - loss: 0.2321 - accuracy: 0.9247
# Epoch 9/16
# 26/26 [==============================] - 0s 18ms/step - loss: 0.2245 - accuracy: 0.9268
# Epoch 10/16
# 26/26 [==============================] - 0s 18ms/step - loss: 0.2176 - accuracy: 0.9296
# Epoch 11/16
# 26/26 [==============================] - 0s 16ms/step - loss: 0.2107 - accuracy: 0.9311
# Epoch 12/16
# 26/26 [==============================] - 1s 19ms/step - loss: 0.2042 - accuracy: 0.9337
# Epoch 13/16
# 26/26 [==============================] - 0s 17ms/step - loss: 0.1979 - accuracy: 0.9365
# Epoch 14/16
# 26/26 [==============================] - 0s 17ms/step - loss: 0.1920 - accuracy: 0.9384
# Epoch 15/16
# 26/26 [==============================] - 0s 17ms/step - loss: 0.1862 - accuracy: 0.9407
# Epoch 16/16
# 26/26 [==============================] - 0s 16ms/step - loss: 0.1809 - accuracy: 0.9416
# 46/46 [==============================] - 0s 2ms/step - loss: 0.5676 - accuracy: 0.7876
#
# Test accuracy: 78.76%

# %%
reg_results = test_model(reg_model, X_train_oh, y_train_oh, X_test_oh, y_test_oh, reg_min)
# Out:
# Epoch 1/5
# 26/26 [==============================] - 1s 36ms/step - loss: 0.2917 - accuracy: 0.9414
# Epoch 2/5
# 26/26 [==============================] - 1s 39ms/step - loss: 0.2642 - accuracy: 0.9506
# Epoch 3/5
# 26/26 [==============================] - 2s 59ms/step - loss: 0.2495 - accuracy: 0.9554
# Epoch 4/5
# 26/26 [==============================] - 1s 38ms/step - loss: 0.2394 - accuracy: 0.9611
# Epoch 5/5
# 26/26 [==============================] - 1s 34ms/step - loss: 0.2289 - accuracy: 0.9642
# 46/46 [==============================] - 0s 4ms/step - loss: 0.7501 - accuracy: 0.7739
#
# Test accuracy: 77.39%

# %%
drop_results = test_model(drop_model, X_train_oh, y_train_oh, X_test_oh, y_test_oh, drop_min)
# Out:
# Epoch 1/7
# 26/26 [==============================] - 1s 36ms/step - loss: 0.2126 - accuracy: 0.9328
# Epoch 2/7
# 26/26 [==============================] - 1s 34ms/step - loss: 0.1947 - accuracy: 0.9372
# Epoch 3/7
# 26/26 [==============================] - 1s 57ms/step - loss: 0.1834 - accuracy: 0.9441
# Epoch 4/7
# 26/26 [==============================] - 2s 84ms/step - loss: 0.1664 - accuracy: 0.9503
# Epoch 5/7
# 26/26 [==============================] - 1s 35ms/step - loss: 0.1606 - accuracy: 0.9505
# Epoch 6/7
# 26/26 [==============================] - 1s 34ms/step - loss: 0.1366 - accuracy: 0.9566
# Epoch 7/7
# 26/26 [==============================] - 1s 33ms/step - loss: 0.1353 - accuracy: 0.9553
# 46/46 [==============================] - 0s 3ms/step - loss: 0.7380 - accuracy: 0.7807
#
# Test accuracy: 78.07%

# %% [markdown]
# # Handling Underfitting
# * In a general situation, the best strategy is to increase the model complexity by either increasing the number of parameters of your deep learning model or the order of your model. Underfitting is due to the model being simpler than needed. It fails to capture the patterns in the data. Increasing the model complexity will lead to improvement in training performance. If we use a large enough model it can even achieve a training error of zero i.e. the model will memorize the data and suffer from over-fitting. The goal is to hit the optimal sweet spot.
# * Try to train the model for more epochs. Ensure that the loss is decreasing gradually over the course of the training. Otherwise, it is highly likely that there is some kind of bug or problem in the training code/logic itself.
# * If you aren’t shuffling the data after every epoch, it can harm the model performance. Ensuring that you are shuffling the data is a good check to perform at this point.

# %% [markdown]
# #Conclusion
# To recap: here are the most common ways to prevent overfitting in neural networks:
#
# * Get more training data.
# * Reduce the capacity of the network.
# * Add weight regularization.
# * Add dropout.
#
# Two important approaches not covered in this guide are:
#
# * data-augmentation
# * batch normalization
#
# Remember that each method can help on its own, but often combining them can be even more effective.
#
# here are the ways to prevent underfitting
#
# * Get more training data.
# * Increase the size or number of parameters in the model.
# * Increase the complexity of the model.
# * Increasing the training time, until cost function is minimised.

# %% [markdown]
# # Bonus content - Visualizing L2 regularization

# %%
import numpy as np
#%matplotlib notebook
# %matplotlib inline
import matplotlib.pyplot as plt
from IPython.core.debugger import set_trace
import warnings
warnings.filterwarnings('ignore')
import itertools

# %%
def plot_contour(f, x1bound, x2bound, resolution, ax):
    x1range = np.linspace(x1bound[0], x1bound[1], resolution)
    x2range = np.linspace(x2bound[0], x2bound[1], resolution)
    xg, yg = np.meshgrid(x1range, x2range)
    zg = np.zeros_like(xg)
    for i,j in itertools.product(range(resolution), range(resolution)):
        zg[i,j] = f([xg[i,j], yg[i,j]])
    ax.contour(xg, yg, zg, 100)
    return ax

# %% [markdown]
# Let's create a toy data:

# %%
N = 20
x = np.random.rand(N) * 10
y = -4*x + 10 + 2*np.random.randn(N)

# %% [markdown]
# visualize the regularized **cost function**

# %%
cost = lambda w: .5*np.mean((w[0] + w[1]*x - y)**2)
l2_penalty = lambda w: np.dot(w,w)/2
cost_plus_l2 = lambda w: cost(w) + 5*l2_penalty(w)

fig, axes = plt.subplots(ncols=3, nrows=1, constrained_layout=True, figsize=(15, 5))
plot_contour(cost, [-20,20], [-20,20], 50, axes[0])
axes[0].set_title(r'cost function $J(w)$')
plot_contour(l2_penalty, [-20,20], [-20,20], 50, axes[1])
axes[1].set_title(r'L2 reg. $||w||_2^2$')
plot_contour(cost_plus_l2, [-20,20], [-20,20], 50, axes[2])
axes[2].set_title(r'L2 reg. cost $J(w) + 5 ||w||_2^2$')
plt.show()

# %% [markdown]
# ## Bonus question: Plot the same for L1 regularization

# %% [markdown]
# ### Answer

# %%
cost = lambda w: .5*np.mean(np.abs(w[0] + w[1]*x - y))
l1_penalty = lambda w: np.dot(w,w)/2
cost_plus_l1 =  lambda w: cost(w) + 5*l2_penalty(w)

fig, axes = plt.subplots(ncols=3, nrows=1, constrained_layout=True, figsize=(15, 5))
plot_contour(cost, [-20,20], [-20,20], 50, axes[0])
axes[0].set_title(r'cost function $J(w)$')
plot_contour(l1_penalty, [-20,20], [-20,20], 50, axes[1])
axes[1].set_title(r'L1 reg. $||w||_2^2$')
plot_contour(cost_plus_l1, [-20,20], [-20,20], 50, axes[2])
axes[2].set_title(r'L1 reg. cost $J(w) + 5 ||w||_2^2$')
plt.show()

# %% [markdown]
# ## Bonus Question 2
# After looking at the visualization to what the L1 and L2 normalizations, how do they help while training?

# %% [markdown]
# # **Upload this Day 9 Colab Notebook to your Github repository under "Day 9" folder. Also add your *Reflection* on today's learning in README.md**
